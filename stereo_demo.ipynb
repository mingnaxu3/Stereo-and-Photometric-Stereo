# %%
# %pylab
# %matplotlib inline
import utils
import stereo_datasets
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
dataset = stereo_datasets.get_dataset('Adirondacks')
plt.figure(); plt.imshow(dataset['left'])
plt.figure(); plt.imshow(dataset['right'])
plt.figure(); plt.imshow(dataset['gt'])
print(dataset['dmax'])
# Out:
# 70

# %%
import stereo
import numpy as np
ncc_vol = stereo.compute_ncc_vol(dataset['right'], dataset['left'], 7, dataset['dmax'])
# Out:
# (49,)
# <class 'numpy.ndarray'>
# (49,)
# <class 'numpy.ndarray'>
# (49,)
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import stereo
#       2 import numpy as np
# ----> 3 ncc_vol = stereo.compute_ncc_vol(dataset['right'], dataset['left'], 7, dataset['dmax'])
#
# File ~/cs4670/PA3_release/stereo.py:79, in compute_ncc_vol(img_right, img_left, patchsize, dmax)
#      61 '''
#      62 Compute the NCC-based cost volume
#      63 Input:
#    (...)
#      76 Your code should call get_ncc_descriptors to compute the descriptors once.
#      77 '''
#      78 height, width = img_left.shape[:2]
# ---> 79 right_ncc_d = get_ncc_descriptors(img_right, patchsize)
#      81 left_ncc_d = get_ncc_descriptors(img_left, patchsize)
#      82 ncc_vol = np.zeros((dmax, height, width))
#
# File ~/cs4670/PA3_release/stereo.py:48, in get_ncc_descriptors(img, patchsize)
#      45     print(type(flat_patch))
#      46     channel_arr.append(np.ndarray.flatten(new_patch))
# ---> 48 flattened = np.ndarray.flatten(channel_arr)
#      49 norm = np.linalg.norm(flattened)
#      50 if norm >= 1e-6:
#
# TypeError: descriptor 'flatten' for 'numpy.ndarray' objects doesn't apply to a 'list' object

# %%
disparity = stereo.get_disparity(ncc_vol)

# %%
disparity = np.clip(disparity, 0, dataset['dmax'])
plt.imshow(disparity)

# %%
error_metric = stereo_datasets.evaluate(disparity, dataset['gt'])
print(error_metric)
# Out:
# 1.0

# %%
dataset = stereo_datasets.get_dataset('Teddy')
plt.figure(); plt.imshow(dataset['left'])
plt.figure(); plt.imshow(dataset['right'])
plt.figure(); plt.imshow(dataset['gt'])
print(dataset['dmax'])
# Out:
# 64

# %%
ncc_vol = stereo.compute_ncc_vol(dataset['right'], dataset['left'], 15, dataset['dmax'])

# %%
disparity = stereo.get_disparity(ncc_vol)

# %%
disparity = np.clip(disparity, 0, dataset['dmax'])
plt.imshow(disparity)

# %%
error_metric = stereo_datasets.evaluate(disparity, dataset['gt'])
print(error_metric)
# Out:
# 1.0
